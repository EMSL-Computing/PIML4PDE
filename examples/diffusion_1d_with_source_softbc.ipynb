# %% [markdown]
# ### **Problem Statement:**
# We aim to solve **1D steady-state diffusion problems** in homogeneous media using the **Physics-Informed Neural Networks (PINN)** approach for solving PDEs, implemented with the JAX library.
#
#
#
# ### **Domain**:
# $$
# \Omega = \{ x \mid 0 \leq x \leq L \}
# $$
#
#
#
# ### **Governing Equation**:
# The 1D steady-state heat conduction in homogeneous medium with a source term is governed by the Diffusion equation as follows:
# <!-- $$
# \frac{\partial}{\partial x} \left( K \frac{\partial h}{\partial x} \right) = 0, \quad \text{in } \Omega.
# $$
#
# For a homogeneous medium where hydraulic conductivity, K is constant, this simplifies to: -->
# $$
# \frac{\partial^2 T}{\partial x^2} = -10 cos(x), \quad \text{in } \Omega.
# $$
#
#
#
# ### **Boundary Conditions**
#
# **Dirichlet Boundary Conditions** (Prescribed temperature on the left and right boundaries):
# $$
# T(0) = T_1, \quad T(L) = T_2.
# $$
#
#
#
# ### **Objective**:
# We solve this problem using Physics-Informed Neural Networks (PINN) to predict the temperature distribution, T(x),  across the domain and compare it with the analytical solution for the same configuration. Trainees will learn how to add source term in the residual and how to change the boundary condition.
#
#
# ---
# **Developed by**:
# Lal Mamud, Postdoc - Subsurface Modeler, Environmental Subsurface Science Group, Energy & Environment Division, Pacific Northwest National Laboratory, Richland, WA, USA.
#
# Pratanu Roy, Staff Scientist, Atmospheric, Earth and Energy Division, Lawrence Livermore National Laboratory, California, USA
#
# **Mentors**:
# Maruti K. Mudunuru and Satish Karra
#
# ---

# %% [markdown]
# ## 1. Import required Python libraries

# %%
import os
import sys
import numpy as np
import jax
import jax.numpy as jnp
from jax import random, jit, grad, vmap, jacfwd, jacrev
import optax
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib as mpl
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ## 2. Define Domain and Boundary Conditions, Generate Collocation Points

# %%
xmin = 0.0  # Left boundary of the domain
xmax = 1.0  # Right boundary of the domain

lb_temp = 0  # Temperature at the left boundary
rb_temp = 0  # Temperature at the right boundary
bcs = [lb_temp, rb_temp]  # Boundary conditions as a list

n_colloc = 100  # Number of collocation points

# Generate random collocation points within the domain
key = jax.random.PRNGKey(0)  # Random seed
#x_colloc = jnp.linspace(xmin, xmax, n_colloc).reshape(-1, 1)
x_colloc = jax.random.uniform(key, shape=(n_colloc, 1), minval=xmin, maxval=xmax)

# Plot the random collocation points
plt.figure(figsize = (5, 4), dpi = 150)
plt.scatter(x_colloc, jnp.zeros_like(x_colloc), color='black', label='Collocation Points', s=5)
plt.xlabel('$x$')
#plt.ylabel('Random Points (Plotted on $y=0$)')
plt.title('Random Collocation Points in 1D Domain')
plt.legend()

# %% [markdown]
# ## 3. Define PDE Residual

# %%
# PDE Residual for 1D heat diffusion with source term
def pde_residual_1d_diffusion(x, h):
    """
    Compute the PDE residual for heat diffusion.

    Args:
        h Lambda function representing the neural network solution h(x).
        x: Collocation points (array of shape Nx1).
    
    Returns:
        pde_res: PDE residual (array of shape Nx1).
    """

    h_hc = lambda x: h(x)

    h_x = lambda x: vmap(jacfwd(h))(x)  # First derivative
    
    h_xx = lambda x: vmap(jacrev(h_x))(x)  # Second derivative
    
    pde_res = h_xx(x).reshape(-1, 1)
    
    return pde_res

# %% [markdown]
# ## 4. Define Neural Network Architecture

# %%
# Function to initialize parameters of the neural network (weights and biases)
def init_mlp(layers, key):
    """
    Initialize the neural network using Xavier initialization.

    Args:
        layers: List defining the number of nodes in each layer (e.g., [1, 50, 50, 1]).
        key: Random key for initialization.
    
    Returns:
        params: Initialized weights and biases for the network.
    """
    params = []
    for i in range(len(layers) - 1):
        key, subkey = random.split(key)
        bound = jnp.sqrt(6. / (layers[i] + layers[i+1]))
        weights = random.uniform(subkey, (layers[i], layers[i+1]), minval=-bound, maxval=bound)
        biases = jnp.zeros(layers[i+1])
        params.append((weights, biases))
    return params



# Define Neural Network Architecture 
def neural_net(params, coord):
    """
    Forward pass through the neural network.

    Args:
        params: Neural network parameters (list of weights and biases).
        coord: Input coordinates (array of shape Nx1).
    
    Returns:
        h_nn: Output of the neural network.
    """
    for w, b in params:
        h_nn = jnp.dot(coord, w) + b
        coord = jnp.tanh(h_nn)  # Activation function
    return h_nn

# %%
# Loss Function
def loss_func(params, x, bcs):
    """
    Compute the total loss for the PINN.

    Args:
        params: Neural network parameters.
        x: Collocation points (array of shape Nx1).
        bcs: Boundary conditions [left_temp, right_temp].
    
    Returns:
        loss: Total loss (scalar).
    """

    h = lambda x: neural_net(params, x)
    
    # PDE residual loss
    pde_res = pde_residual_1d_diffusion(x, h) + 10*jnp.cos(x)
    
    pde_loss = jnp.mean(pde_res**2)  # Ensure this is scalar

    # Boundary condition loss
    left_bc_loss = (h(xmin) - bcs[0])**2
    
    right_bc_loss = (h(xmax) - bcs[1])**2
    
    bc_loss = left_bc_loss + right_bc_loss  # Ensure scalar addition

    # Total loss
    loss = pde_loss + bc_loss
    
    return jnp.sum(loss)  # Return scalar

# %% [markdown]
# ## 6. Define Hyperparameters and Training Loop
# This cell contains the training loop for the Physics-Informed Neural Network (PINN). It includes functions and code to update the network parameters, compute the loss, track training progress, and identify the best-performing model during the training process.

# %%
# Training PINN
n_hl = 3  # Number of hidden layers
n_nodes = 8  # Number of nodes per layer
lr = 1E-2  # Learning rate
epoch = 10000  # Number of epochs

layers = [1, n_nodes, 1]  # Neural network architecture
soln_type = 1  # Solution type: 0 = homogeneous, 1 = heterogeneous

# Initialize neural network
key = random.PRNGKey(1234)
params = init_mlp(layers, key)

# Initialize optimizer
optimizer = optax.adam(learning_rate=lr)
opt_state = optimizer.init(params)


# Parameters update function
@jit
def update(params, opt_state, x):
    """
    Perform one optimization step.

    Args:
        params: Neural network parameters.
        opt_state: Optimizer state.
        x: Collocation points.
    
    Returns:
        value: Current loss.
        params: Updated parameters.
        opt_state: Updated optimizer state.
    """
    value, grads = jax.value_and_grad(loss_func)(params, x, bcs)
    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
    return value, params, opt_state


#%% Training loop
# Initialize lists to track all losses and epochs
all_losses = []
all_epochs = []

# Initialize tracking variables
min_loss = jnp.inf
best_params = None

for i in range(epoch + 1):
    loss, params, opt_state = update(params, opt_state, x_colloc)
    all_losses.append(loss)
    all_epochs.append(i)
    if loss < min_loss:
        min_loss = loss
        best_params = params
        best_iteration = i
    if i % 100 == 0:
        print(f"Epoch {i}: Loss = {loss:.4e}")

print(f" ")
print(f"Best Model:")
print(f"Best loss: {min_loss:.4e} at iteration {best_iteration}")
print(f" ")
# Out:
# Epoch 0: Loss = 7.1702e+01
# Epoch 100: Loss = 6.9886e+00
# Epoch 200: Loss = 2.3187e-01
# Epoch 300: Loss = 3.5364e-02
# Epoch 400: Loss = 3.2504e-02
# Epoch 500: Loss = 2.9830e-02
# Epoch 600: Loss = 2.7308e-02
# Epoch 700: Loss = 2.4952e-02
# Epoch 800: Loss = 2.2760e-02
# Epoch 900: Loss = 2.0724e-02
# Epoch 1000: Loss = 1.8832e-02
# Epoch 1100: Loss = 1.7073e-02
# Epoch 1200: Loss = 1.5439e-02
# Epoch 1300: Loss = 1.3920e-02
# Epoch 1400: Loss = 1.2509e-02
# Epoch 1500: Loss = 1.1200e-02
# Epoch 1600: Loss = 9.9850e-03
# Epoch 1700: Loss = 8.8592e-03
# Epoch 1800: Loss = 7.8179e-03
# Epoch 1900: Loss = 6.8569e-03
# Epoch 2000: Loss = 5.9732e-03
# Epoch 2100: Loss = 5.1644e-03
# Epoch 2200: Loss = 4.4283e-03
# Epoch 2300: Loss = 3.7633e-03
# Epoch 2400: Loss = 3.1675e-03
# Epoch 2500: Loss = 2.6391e-03
# Epoch 2600: Loss = 2.1760e-03
# Epoch 2700: Loss = 1.7751e-03
# Epoch 2800: Loss = 1.4333e-03
# Epoch 2900: Loss = 1.1465e-03
# Epoch 3000: Loss = 9.0988e-04
# Epoch 3100: Loss = 7.1846e-04
# Epoch 3200: Loss = 5.6658e-04
# Epoch 3300: Loss = 4.4855e-04
# Epoch 3400: Loss = 3.5869e-04
# Epoch 3500: Loss = 2.9163e-04
# Epoch 3600: Loss = 2.4252e-04
# Epoch 3700: Loss = 2.0708e-04
# Epoch 3800: Loss = 1.8183e-04
# Epoch 3900: Loss = 1.6394e-04
# Epoch 4000: Loss = 1.5129e-04
# Epoch 4100: Loss = 1.4244e-04
# Epoch 4200: Loss = 1.4012e-04
# Epoch 4300: Loss = 1.3140e-04
# Epoch 4400: Loss = 4.4218e-04
# Epoch 4500: Loss = 1.2544e-04
# Epoch 4600: Loss = 1.2351e-04
# Epoch 4700: Loss = 1.2189e-04
# Epoch 4800: Loss = 1.2064e-04
# Epoch 4900: Loss = 1.1951e-04
# Epoch 5000: Loss = 1.1852e-04
# Epoch 5100: Loss = 1.1793e-04
# Epoch 5200: Loss = 1.1679e-04
# Epoch 5300: Loss = 1.2049e-04
# Epoch 5400: Loss = 1.1520e-04
# Epoch 5500: Loss = 4.7116e-04
# Epoch 5600: Loss = 1.1364e-04
# Epoch 5700: Loss = 1.1287e-04
# Epoch 5800: Loss = 1.1206e-04
# Epoch 5900: Loss = 1.1123e-04
# Epoch 6000: Loss = 1.3558e-04
# Epoch 6100: Loss = 1.1049e-04
# Epoch 6200: Loss = 1.5759e-04
# Epoch 6300: Loss = 1.3630e-04
# Epoch 6400: Loss = 2.1472e-04
# Epoch 6500: Loss = 1.0714e-04
# Epoch 6600: Loss = 1.1132e-04
# Epoch 6700: Loss = 1.0499e-04
# Epoch 6800: Loss = 1.0726e-04
# Epoch 6900: Loss = 1.0417e-04
# Epoch 7000: Loss = 2.2256e-04
# Epoch 7100: Loss = 1.0130e-04
# Epoch 7200: Loss = 4.3223e-04
# Epoch 7300: Loss = 3.2596e-04
# Epoch 7400: Loss = 9.8530e-05
# Epoch 7500: Loss = 1.0928e-04
# Epoch 7600: Loss = 9.6811e-05
# Epoch 7700: Loss = 9.6425e-05
# Epoch 7800: Loss = 7.2917e-04
# Epoch 7900: Loss = 9.4284e-05
# Epoch 8000: Loss = 1.0170e-04
# Epoch 8100: Loss = 9.2531e-05
# Epoch 8200: Loss = 1.2817e-04
# Epoch 8300: Loss = 9.0938e-05
# Epoch 8400: Loss = 9.0335e-05
# Epoch 8500: Loss = 8.9311e-05
# Epoch 8600: Loss = 9.0809e-05
# Epoch 8700: Loss = 8.7798e-05
# Epoch 8800: Loss = 8.8832e-05
# Epoch 8900: Loss = 8.6437e-05
# Epoch 9000: Loss = 8.5914e-05
# Epoch 9100: Loss = 8.4833e-05
# Epoch 9200: Loss = 8.5936e-05
# Epoch 9300: Loss = 8.3447e-05
# Epoch 9400: Loss = 8.4698e-05
# Epoch 9500: Loss = 8.5969e-05
# Epoch 9600: Loss = 8.1441e-05
# Epoch 9700: Loss = 1.0897e-04
# Epoch 9800: Loss = 8.0174e-05
# Epoch 9900: Loss = 8.0675e-05
# Epoch 10000: Loss = 1.6245e-04
#
# Best Model:
# Best loss: 7.9087e-05 at iteration 9973

# %% [markdown]
# ## 7. Plot pinn loss during training

# %%
def plot_pinn_training(all_losses, all_epochs):
    plt.figure(figsize = (5, 4), dpi = 150)
    plt.semilogy(all_epochs, all_losses, '-r', markersize = 4, linewidth = 1.0)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    #plt.legend(prop={"size": fontsize_legend}, loc="best")
    plt.xlim(min(all_epochs), max(all_epochs))
    plt.tight_layout()
    
plot_pinn_training(all_losses, all_epochs)

# %% [markdown]
# ## 8. PINN prediction and plotting results

# %%
nx = 20
x = np.linspace(xmin, xmax, nx)
x = np.linspace(xmin, xmax, nx).reshape(-1, 1)  # Reshape to (nx, 1) to match neural_net input


# Predict temperature using the trained neural network
T_pinn = neural_net(best_params, x)  # Output will be (nx, 1)
print(T_pinn)
# Out:
# [[1.8191338e-04]
#  [2.2830141e-01]
#  [4.2875361e-01]
#  [6.0162985e-01]
#  [7.4715316e-01]
#  [8.6561596e-01]
#  [9.5736277e-01]
#  [1.0227960e+00]
#  [1.0623811e+00]
#  [1.0766698e+00]
#  [1.0662915e+00]
#  [1.0319594e+00]
#  [9.7445929e-01]
#  [8.9463294e-01]
#  [7.9337299e-01]
#  [6.7162049e-01]
#  [5.3035963e-01]
#  [3.7063086e-01]
#  [1.9354117e-01]
#  [2.8681755e-04]]

# %%
def plot_temp_solutions(coords, pinn_temp):
    plt.figure(figsize = (5, 4), dpi = 150)
    plt.plot(coords, pinn_temp, '--', color='red', markersize = 4,  markerfacecolor = 'green', linewidth = 1.25, label="PINN")
    plt.xlabel("X")
    plt.ylabel("Temperature")
    plt.title("PINN solution for temperature distribution")
    plt.xlim(np.min(coords), np.max(coords))
    plt.tight_layout()
plot_temp_solutions(x, T_pinn )

# %% [markdown]
# ## 9. Solution verifications

# %%
# analytical solution of this homogeneous 1D case
def exact_solution_homo(x_coords):
    temp_exact = 10.0*((jnp.cos(x_coords)-1) + x_coords*(1-jnp.cos(1)))
    return temp_exact  

h_exact = exact_solution_homo(x)
print(h_exact)

# def plot_head_solutions_as_pinn(coords, pinn_head, exact_head):
#     plt.figure(figsize = (5, 4))
#     plt.plot(coords, exact_head, color='Black', linestyle='-', linewidth = 1.25, label="Analytical")
#     plt.plot(coords, pinn_head, '--', color='red', markersize = 4,  markerfacecolor = 'green', linewidth = 1.25, label="PINN")
#     plt.xlabel("X [L]")
#     plt.ylabel("Head [L]")
#     plt.legend(loc="upper right")
#     plt.tight_layout()
# plot_head_solutions_as_pinn(x, h_pinn, h_exact)
# Out:
# [[0.        ]
#  [0.22809881]
#  [0.42854166]
#  [0.6014436 ]
#  [0.74699533]
#  [0.865464  ]
#  [0.95719206]
#  [1.0225947 ]
#  [1.0621617 ]
#  [1.0764527 ]
#  [1.0660989 ]
#  [1.0317984 ]
#  [0.9743169 ]
#  [0.89448273]
#  [0.7931885 ]
#  [0.67138314]
#  [0.53007543]
#  [0.37032604]
#  [0.1932472 ]
#  [0.        ]]

# %%
def plot_temp_solutions_as_pinn(coords, pinn_temp, exact_temp):
    plt.figure(figsize = (5, 4), dpi = 150)
    plt.plot(coords, exact_temp, color='Black', linestyle='-', linewidth = 1.0, label="Analytical")
    plt.plot(coords, pinn_temp, '--', color='red', markersize = 4,  markerfacecolor = 'green', linewidth = 1.5, label="PINN")
    plt.xlabel("X")
    plt.ylabel("Temperature")
    plt.legend(loc="upper right")
    plt.xlim(np.min(coords), np.max(coords))
    plt.tight_layout()
plot_temp_solutions_as_pinn(x, T_pinn, h_exact)

# %% [markdown]
# ## 10. Error analysis between the analytical solution and PINN prediction

# %%
# Analytical solution and PINN predictions are already 1D
analytical_Pr = h_exact.flatten()  # Flatten the analytical solution (if necessary)
pinn_Pr = T_pinn.flatten()  # Flatten the PINN predictions (if necessary)

# Perform regression
reg = LinearRegression()
reg.fit(analytical_Pr.reshape(-1, 1), pinn_Pr)  # Fit the model

# Predict using the regression model
y_pred = reg.predict(analytical_Pr.reshape(-1, 1))

# Calculate R^2 score
r2 = r2_score(pinn_Pr, y_pred)

# Calculate RMSE
mse = mean_squared_error(pinn_Pr, y_pred)  # Mean Squared Error
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Print results
print(f"R^2 Score: {r2:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
# Out:
# R^2 Score: 1.0000
# Root Mean Squared Error (RMSE): 0.0000

# %%
#%% Plotting Regression
plt.figure(figsize = (5, 4), dpi = 150)
plt.scatter(analytical_Pr, pinn_Pr, label="Data Points", color="blue", alpha=0.7)
plt.plot(analytical_Pr, y_pred, label="Regression Line", color="red", linewidth=2)

# Add annotations for RMSE and R^2
plt.text(
    0.05,
    0.95,
    f"$R^2$ = {r2:.4f}\nRMSE = {rmse:.4f}",
    transform=plt.gca().transAxes,
    fontsize=12,
    verticalalignment="top",
    bbox=dict(boxstyle="round", facecolor="white", alpha=0.8),
)

plt.xlabel("Analytical Solution")
plt.ylabel("PINN Prediction")
plt.title("Regression Plot: Analytical vs. PINN Predictions")
plt.legend(loc="lower right")
plt.show()

# %%
#%% Plotting Error
# Calculate percentage error
error_percentage = 100 * (analytical_Pr - pinn_Pr) / analytical_Pr
plt.figure(figsize = (5, 4), dpi = 150)
plt.plot(x, error_percentage, label="Error (%)", color="red", marker="o")
plt.xlabel("$x$")
plt.ylabel("$Error (\%)$")
plt.title("Percentage Error Between Analytical and PINN Solution")
plt.legend()
plt.show()
